# %%
import pandas
import magic
import os
import glob
import datetime
from collections import OrderedDict

# %%
import apes

# %% [markdown]
# ## Test

# %%
from apes.utils.path import data_root, get_data
from apes.core.basedata import BaseData, SourceData, CSVSourceData

# %%
file_name = 'sourcedata/sample.csv'
tagl = ['gdp', '2018', '2017', '2013', 'poverty']

# %% [markdown]
# ### path

# %%
data_root()
# Out:
# '/Users/jinningwang/Documents/work/apes/datasets'

# %%
get_data(file_name)
# Out:
# '/Users/jinningwang/Documents/work/apes/datasets/sourcedata/sample.csv'

# %% [markdown]
# ### BaseData

# %%
based = BaseData(file_name,
                 name='sample',
                 info='Sample of CAGDP9', tag=tagl)

# %%
based
# Out:
# Class: BaseData
# Data name: sample
# Data type: csv
# Data size: 18.68 KB
# Is split: False
# Created at: 2022-11-10, 10:51:59
# Last modified at: 2022-11-09, 21:48:43
# Last accessed at: 2022-11-10, 14:40:54
# Is split: False
# Stored as: /Users/jinningwang/Documents/work/apes/datasets/sourcedata/sample.csv

# %%
based.tag
# Out:
# OrderedDict([('power', []),
#              ('energy', []),
#              ('economy', ['gdp']),
#              ('demography', []),
#              ('geography', []),
#              ('time', ['2018', '2017', '2013']),
#              ('ungrouped', ['poverty'])])

# %%
based.attr
# Out:
# OrderedDict([('name', 'sample'),
#              ('info', 'Sample of CAGDP9'),
#              ('file_name', 'sample.csv'),
#              ('size', '18.68 KB'),
#              ('type', 'csv'),
#              ('created_time', '2022-11-10, 10:51:59'),
#              ('modified_time', '2022-11-09, 21:48:43'),
#              ('accessed_time', '2022-11-10, 14:40:54'),
#              ('url', None),
#              ('doi', None),
#              ('lic', None)])

# %% [markdown]
# ### SourceData

# %%
sourced = SourceData(file_name,
                     name='sample',
                     info='Sample of CAGDP9', tag=tagl,
                     url='sample_url', doi='sample_doi',
                     lic='sample_lic')

# %%
sourced
# Out:
# Class: SourceData
# Data name: sample
# Data type: csv
# Data size: 18.68 KB
# Is split: False
# Created at: 2022-11-10, 10:51:59
# Last modified at: 2022-11-09, 21:48:43
# Last accessed at: 2022-11-10, 14:40:54
# Is split: False
# Stored as: /Users/jinningwang/Documents/work/apes/datasets/sourcedata/sample.csv

# %%
sourced.tag
# Out:
# OrderedDict([('power', []),
#              ('energy', []),
#              ('economy', ['gdp']),
#              ('demography', []),
#              ('geography', []),
#              ('time', ['2018', '2017', '2013']),
#              ('ungrouped', ['poverty'])])

# %% [markdown]
# ### Split data

# %%
sfile_name = 'sourcedata/sample_split'
baseds = BaseData(sfile_name,
                  name='sample',
                  info='Sample of CAGDP9', tag=tagl)

# %%
baseds
# Out:
# Class: BaseData
# Data name: sample
# Data type: Multiple files, ['csv']
# Data size: 18.92 KB
# Is split: True
# Created at: 2022-11-10, 10:52:34
# Last modified at: 2022-11-10, 10:52:34
# Last accessed at: 2022-11-10, 10:52:34
# Is split: True
# Stored in: /Users/jinningwang/Documents/work/apes/datasets/sourcedata/sample_split

# %% [markdown]
# ### CSV Data

# %%
sfile_name = 'sourcedata/sample_split'
tagl = ['gdp', '2018', '2017', '2013', 'poverty']
csvsdata = CSVSourceData(sfile_name,
                         name='sample',
                         info='Sample of CAGDP9', tag=tagl)

# %%
csvsdata.as_df()
# Out:
#      GeoFIPS        GeoName  Region TableName  LineCode  \
# 0    "09000"    Connecticut       1    CAGDP9         1
# 1    "09000"    Connecticut       1    CAGDP9         2
# 2    "09000"    Connecticut       1    CAGDP9         3
# 3    "09000"    Connecticut       1    CAGDP9         6
# 4    "09000"    Connecticut       1    CAGDP9        10
# ..       ...            ...     ...       ...       ...
# 63   "09001"  Fairfield, CT       1    CAGDP9        88
# 64   "09001"  Fairfield, CT       1    CAGDP9        89
# 65   "09001"  Fairfield, CT       1    CAGDP9        90
# 66   "09001"  Fairfield, CT       1    CAGDP9        91
# 67   "09001"  Fairfield, CT       1    CAGDP9        92
#
#    IndustryClassification                                      Description  \
# 0                     ...                               All industry total
# 1                     ...                               Private industries
# 2                      11       Agriculture, forestry, fishing and hunting
# 3                      21    Mining, quarrying, and oil and gas extraction
# 4                      22                                        Utilities
# ..                    ...                                              ...
# 63              42, 44-45                                            Trade
# 64              22, 48-49                     Transportation and utilities
# 65              31-33, 51                    Manufacturing and information
# 66                    ...            Private goods-producing industries 2/
# 67                    ...         Private services-providing industries 3/
#
#                                  Unit       2001       2002  ...       2011  \
# 0   Thousands of chained 2012 dollars  218135261  216677688  ...  238542385
# 1   Thousands of chained 2012 dollars  193886730  192051189  ...  213757827
# 2   Thousands of chained 2012 dollars     547315     537637  ...     388922
# 3   Thousands of chained 2012 dollars     304457     292162  ...     130510
# 4   Thousands of chained 2012 dollars    3236048    3166608  ...    4170052
# ..                                ...        ...        ...  ...        ...
# 63  Thousands of chained 2012 dollars    9935462    9733878  ...    9464986
# 64  Thousands of chained 2012 dollars    1649636    1583996  ...    1964717
# 65  Thousands of chained 2012 dollars   11827669   13930397  ...   16399594
# 66  Thousands of chained 2012 dollars   12483164   14667980  ...   14045843
# 67  Thousands of chained 2012 dollars   59172858   57090966  ...   61542781
#
#          2012       2013       2014       2015       2016       2017  \
# 0   240911922  236050641  235780926  242706532  243286679  247358533
# 1   216663938  211850503  211696714  218349477  218981181  223001214
# 2      412486     415340     371603     458637     445665     446142
# 3      156720     157321     188850     268208     337061     189990
# 4     4787031    4682392    4658404    4213794    4012273    3935763
# ..        ...        ...        ...        ...        ...        ...
# 63    9872366   10190356   10561502   11166414   11112208   10783355
# 64    2878183    2465931    3024615    3370144    2808094    2308162
# 65   15203451   14984891   14560232   14349311   13667739   13447266
# 66   13131323   12012249   11498059   10441747    9270769    8604594
# 67   64967353   63558108   63516167   65416214   66086957   67389096
#
#          2018       2019       2020
# 0   249998102  251495134  235888558
# 1   226422017  228532688  213416926
# 2      420935     457907     482213
# 3      185311     184674     183964
# 4     4014921    4097441    4277371
# ..        ...        ...        ...
# 63   10756379   10411702   10030449
# 64    2320116    2100345    2072942
# 65   14134809   14658781   13981147
# 66    8525289    8124425    7544532
# 67   68970456   69149985   65024923
#
# [68 rows x 28 columns]

# %%
csvsdata.head()
# Out:
#     GeoFIPS      GeoName  Region TableName  LineCode IndustryClassification  \
# 0   "09000"  Connecticut       1    CAGDP9         1                    ...
# 1   "09000"  Connecticut       1    CAGDP9         2                    ...
# 2   "09000"  Connecticut       1    CAGDP9         3                     11
# 3   "09000"  Connecticut       1    CAGDP9         6                     21
# 4   "09000"  Connecticut       1    CAGDP9        10                     22
#
#                                        Description  \
# 0                               All industry total
# 1                               Private industries
# 2       Agriculture, forestry, fishing and hunting
# 3    Mining, quarrying, and oil and gas extraction
# 4                                        Utilities
#
#                                 Unit       2001       2002  ...       2011  \
# 0  Thousands of chained 2012 dollars  218135261  216677688  ...  238542385
# 1  Thousands of chained 2012 dollars  193886730  192051189  ...  213757827
# 2  Thousands of chained 2012 dollars     547315     537637  ...     388922
# 3  Thousands of chained 2012 dollars     304457     292162  ...     130510
# 4  Thousands of chained 2012 dollars    3236048    3166608  ...    4170052
#
#         2012       2013       2014       2015       2016       2017  \
# 0  240911922  236050641  235780926  242706532  243286679  247358533
# 1  216663938  211850503  211696714  218349477  218981181  223001214
# 2     412486     415340     371603     458637     445665     446142
# 3     156720     157321     188850     268208     337061     189990
# 4    4787031    4682392    4658404    4213794    4012273    3935763
#
#         2018       2019       2020
# 0  249998102  251495134  235888558
# 1  226422017  228532688  213416926
# 2     420935     457907     482213
# 3     185311     184674     183964
# 4    4014921    4097441    4277371
#
# [5 rows x 28 columns]

# %%
file_name = 'sourcedata/sample.csv'
tagl = ['gdp', '2018', '2017', '2013', 'poverty']

csvdata = CSVSourceData(file_name,
                        name='sample',
                        info='Sample of CAGDP9', tag=tagl,
                        url='sample_url', doi='sample_doi',
                        lic='sample_lic')

# %%
csvdata
# Out:
# Class: CSVSourceData
# Data name: sample
# Data type: csv
# Data size: 18.68 KB
# Is split: False
# Created at: 2022-11-10, 10:51:59
# Last modified at: 2022-11-09, 21:48:43
# Last accessed at: 2022-11-10, 14:40:54
# Is split: False
# Stored as: /Users/jinningwang/Documents/work/apes/datasets/sourcedata/sample.csv

# %%
csvdata.as_df()
# Out:
#      GeoFIPS        GeoName  Region TableName  LineCode  \
# 0    "09000"    Connecticut       1    CAGDP9         1
# 1    "09000"    Connecticut       1    CAGDP9         2
# 2    "09000"    Connecticut       1    CAGDP9         3
# 3    "09000"    Connecticut       1    CAGDP9         6
# 4    "09000"    Connecticut       1    CAGDP9        10
# ..       ...            ...     ...       ...       ...
# 63   "09001"  Fairfield, CT       1    CAGDP9        88
# 64   "09001"  Fairfield, CT       1    CAGDP9        89
# 65   "09001"  Fairfield, CT       1    CAGDP9        90
# 66   "09001"  Fairfield, CT       1    CAGDP9        91
# 67   "09001"  Fairfield, CT       1    CAGDP9        92
#
#    IndustryClassification                                      Description  \
# 0                     ...                               All industry total
# 1                     ...                               Private industries
# 2                      11       Agriculture, forestry, fishing and hunting
# 3                      21    Mining, quarrying, and oil and gas extraction
# 4                      22                                        Utilities
# ..                    ...                                              ...
# 63              42, 44-45                                            Trade
# 64              22, 48-49                     Transportation and utilities
# 65              31-33, 51                    Manufacturing and information
# 66                    ...            Private goods-producing industries 2/
# 67                    ...         Private services-providing industries 3/
#
#                                  Unit       2001       2002  ...       2011  \
# 0   Thousands of chained 2012 dollars  218135261  216677688  ...  238542385
# 1   Thousands of chained 2012 dollars  193886730  192051189  ...  213757827
# 2   Thousands of chained 2012 dollars     547315     537637  ...     388922
# 3   Thousands of chained 2012 dollars     304457     292162  ...     130510
# 4   Thousands of chained 2012 dollars    3236048    3166608  ...    4170052
# ..                                ...        ...        ...  ...        ...
# 63  Thousands of chained 2012 dollars    9935462    9733878  ...    9464986
# 64  Thousands of chained 2012 dollars    1649636    1583996  ...    1964717
# 65  Thousands of chained 2012 dollars   11827669   13930397  ...   16399594
# 66  Thousands of chained 2012 dollars   12483164   14667980  ...   14045843
# 67  Thousands of chained 2012 dollars   59172858   57090966  ...   61542781
#
#          2012       2013       2014       2015       2016       2017  \
# 0   240911922  236050641  235780926  242706532  243286679  247358533
# 1   216663938  211850503  211696714  218349477  218981181  223001214
# 2      412486     415340     371603     458637     445665     446142
# 3      156720     157321     188850     268208     337061     189990
# 4     4787031    4682392    4658404    4213794    4012273    3935763
# ..        ...        ...        ...        ...        ...        ...
# 63    9872366   10190356   10561502   11166414   11112208   10783355
# 64    2878183    2465931    3024615    3370144    2808094    2308162
# 65   15203451   14984891   14560232   14349311   13667739   13447266
# 66   13131323   12012249   11498059   10441747    9270769    8604594
# 67   64967353   63558108   63516167   65416214   66086957   67389096
#
#          2018       2019       2020
# 0   249998102  251495134  235888558
# 1   226422017  228532688  213416926
# 2      420935     457907     482213
# 3      185311     184674     183964
# 4     4014921    4097441    4277371
# ..        ...        ...        ...
# 63   10756379   10411702   10030449
# 64    2320116    2100345    2072942
# 65   14134809   14658781   13981147
# 66    8525289    8124425    7544532
# 67   68970456   69149985   65024923
#
# [68 rows x 28 columns]
